# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffinnn/exercicio_py/blob/main/exercicios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("Par")
else:
    print("Ímpar")

# %%
valor_compra = float(input("Digite o valor da compra: "))
cliente_vip = input("Cliente VIP? (s/n): ")

desconto = 0

if valor_compra > 100:
    desconto = 10

if valor_compra > 200:
    desconto = 20

if cliente_vip == "s":
    desconto = desconto + 5

valor_final = valor_compra * (desconto / 100)

print("Desconto aplicado:", desconto, "%")
print("Valor final:", (valor_compra - valor_final))
# Out:
# Digite o valor da compra: 105
# Cliente VIP? (s/n): n
# Desconto aplicado: 10 %
# Valor final: 94.5

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == usuario_correto:
    print("Usuário correto")
    if senha == senha_correta:
     print("Login realizado")
    else:
     print("Senha incorreta")
else:
    print("Usuário incorreto")
# Out:
# Usuário: ad
# Senha: 12
# Usuário incorreto

# %%
quantidade = int(input("Quantos números deseja digitar? "))

maior = 0
menor = 0

for i in range(quantidade):
    numero = int(input("Digite um número: "))

    if numero > maior:
        maior = numero

    if numero < menor:
        menor = numero

print("Maior valor:", maior)
print("Menor valor:", menor)
# Out:
# Quantos números deseja digitar? 5
# Digite um número: 4
# Digite um número: 5
# Digite um número: 6
# Digite um número: 7
# Digite um número: 8
# Maior valor: 8
# Menor valor: 0

# %%
saldo = 1000
opcao = 0

while opcao != 4:
    print("\n=== BANCO ===")
    print("1 - Depositar")
    print("2 - Sacar")
    print("3 - Ver saldo")
    print("4 - Sair")

    opcao = int(input("Escolha uma opção: "))

    if opcao == 1:
        valor = float(input("Valor do depósito: "))
        saldo += valor

    elif opcao == 2:
        valor = float(input("Valor do saque: "))

        if valor <= saldo:
            saldo = saldo - valor
            print("Saque realizado")
        else:
            print("Saldo insuficiente")

    elif opcao == 3:
        print("Saldo atual:", saldo)

print("Sistema encerrado")
# Out:
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 1
# Valor do depósito: 300
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 3
# Saldo atual: 1300.0
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 2
# Valor do saque: 400
# Saque realizado
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 3
# Saldo atual: 900.0
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair

# %%
cand1 = 0
cand2 = 0
cand3 = 0
brancos = 0

quantidade = int(input("Quantidade de eleitores: "))

for i in range(quantidade):
    print("\n1 - Candidato A")
    print("2 - Candidato B")
    print("3 - Candidato C")
    print("0 - Branco")

    voto = int(input("Digite seu voto: "))

    if voto == 1:
        cand1 += 1

    elif voto == 2:
        cand2 + 1

    elif voto == 3:
        cand2 += 1

    else:
        brancos += 1

print("\n=== RESULTADO ===")
print("Candidato A:", cand1)
print("Candidato B:", cand2)
print("Candidato C:", cand3)
print("Brancos:", brancos)

if cand1 > cand2 and cand1 > cand3:
    print("Candidato A venceu")

elif cand2 > cand1 and cand2 > cand3:
    print("Candidato B venceu")

else:
    print("Candidato C venceu")
